# %% [markdown]
# <a href="https://colab.research.google.com/github/pratiwiyasmin0-web/Laporan_Praktikum_EDA/blob/main/NumPy%26Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

harga = np.array([5000, 7000, 3000, 12000, 4500])
print('Rata-rata harga:', harga.mean())
print('Harga tertinggi:', harga.max())
print('Harga setelah diskon 10%:', harga * 0.9)
# Out:
# Rata-rata harga: 6300.0
# Harga tertinggi: 12000
# Harga setelah diskon 10%: [ 4500.  6300.  2700. 10800.  4050.]

# %% [markdown]
# **JAWABAN LATIHAN 1** :
#
# Hasil dari perintah harga * 0.9 pada NumPy array akan otomatis mengalikan setiap elemen angka di dalamnya dengan 0.9 untuk menghitung diskon. Jika hanya menggunakan list Python biasa ([5000, 7000, 3000] * 0.9), eksekusi akan menghasilkan TypeError. Operasi perkalian pada list bawaan Python tidak menerapkan fungsi matematis vectorized ke setiap elemen, melainkan hanya mendukung perkalian dengan bilangan bulat (integer) untuk menggandakan atau mengulang urutan elemen di dalam list tersebut.

# %%
import pandas as pd

data_kantin = {
 'menu': ['Nasi Goreng', 'Es Teh', 'Mie Ayam', 'Es Teh', None],
 'harga': [12000, 4000, 10000, 4000, 8000],
 'terjual': [23, 40, None, 35, 18]
}
df = pd.DataFrame(data_kantin)
print(df)
# Out:
#           menu  harga  terjual
# 0  Nasi Goreng  12000     23.0
# 1       Es Teh   4000     40.0
# 2     Mie Ayam  10000      NaN
# 3       Es Teh   4000     35.0
# 4         None   8000     18.0

# %% [markdown]
# **JAWABAN LATIHAN 2** :
#
# Berdasarkan pendefinisian data_kantin, kolom menu memiliki data kosong (None) pada baris kelima, dan kolom terjual memiliki data kosong pada baris ketiga. Jika data ini langsung dianalisis tanpa dibersihkan, fungsi agregasi (seperti .sum() atau .mean()) dapat menghasilkan error, perhitungan total pendapatan menjadi tidak valid, dan insight yang dihasilkan akan bias.

# %%
import pandas as pd
df = pd.read_csv('data_kantin.csv')

print(df.head()) # 5 baris pertama
print(df.info()) # tipe data & jumlah non-null tiap kolom
print(df.describe()) # statistik ringkas kolom numerik
print(df.shape) # jumlah (baris, kolom)
# Out:
#       tanggal         menu kategori  harga  terjual
# 0  2026-08-20   Teh Hangat  Minuman   3000     11.0
# 1  2026-08-31  Nasi Goreng  Makanan  12000     29.0
# 2  2026-08-21  Nasi Goreng  Makanan  12000     28.0
# 3  2026-08-28   Teh Hangat  Minuman   3000     12.0
# 4  2026-08-21     Es Jeruk  Minuman   5000     19.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   110 non-null    object
#  1   menu      107 non-null    object
#  2   kategori  110 non-null    object
#  3   harga     110 non-null    int64
#  4   terjual   104 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.4+ KB
# None
#               harga     terjual
# count    110.000000  104.000000
# mean    6336.363636   22.923077
# std     3520.001232   10.831178
# min     2000.000000    8.000000
# 25%     3000.000000   13.000000
# ...

# %% [markdown]
# **  JAWABAN LATIHAN 3 **:
#
# Jika hasil dari df.info() menunjukkan ada kolom yang jumlah non-null-nya lebih sedikit dari jumlah baris total dataset, artinya kolom tersebut mengandung missing value (data kosong, NaN, atau None).

# %%
print(df.isnull().sum()) # jumlah data kosong tiap kolom
df['terjual'] = df['terjual'].fillna(0) # isi kekosongan dengan 0
df = df.dropna(subset=['menu']) # hapus baris jika kolom menu kosong
# Out:
# tanggal     0
# menu        3
# kategori    0
# harga       0
# terjual     6
# dtype: int64

# %% [markdown]
# **JAWABAN LATIHAN 4** :
#
# Metode fillna(0) digunakan pada kolom terjual karena sangat logis secara bisnis jika sebuah menu memang tidak laku atau terjual sebanyak 0 porsi pada periode tersebut. Sebaliknya, baris dengan kolom menu yang kosong dihapus menggunakan dropna karena entitas utamanya tidak diketahui. Jika nama barang tidak ada, data harga dan jumlah terjual kehilangan konteksnya sehingga tidak relevan untuk dipertahankan.

# %%
print(df.duplicated().sum()) # jumlah baris duplikat
df = df.drop_duplicates()
df['harga'] = df['harga'].astype(int) # memastikan tipe data harga adalah integer
# Out:
# 0

# %% [markdown]
# **JAWABAN LATIHAN 5** :
#
# Setelah menerapkan fungsi drop_duplicates(), jumlah baris dataset menjadi 4. Terdapat satu baris duplikat ('Es Teh' dengan harga 4000) yang dihapus dari total 5 baris awal. Memastikan tipe data sudah benar (seperti integer untuk harga) menggunakan dtypes sangat esensial agar operasi manipulasi lanjutan seperti perkalian antara harga dan jumlah terjual dapat dieksekusi tanpa kendala komputasi.

# %%
laris = df[df['terjual'] > 20] # filtering
urut = df.sort_values(by='terjual', ascending=False) # sorting
df['total_pendapatan'] = df['harga'] * df['terjual'] # kolom turunan
ringkasan = df.groupby('menu')['total_pendapatan'].sum() # agregasi
print(ringkasan)
# Out:
# menu
# Es Jeruk       1460000.0
# Es Teh         2144000.0
# Kerupuk         972000.0
# Mie Ayam       2410000.0
# Nasi Goreng    3924000.0
# Roti Bakar     1288000.0
# Teh Hangat      459000.0
# Name: total_pendapatan, dtype: float64

# %% [markdown]
# **JAWABAN LATIHAN 6** :
#
# Berdasarkan agregasi dari fungsi groupby, 'Nasi Goreng' menghasilkan total_pendapatan tertinggi (Rp276.000). Informasi ini sangat krusial untuk pengambilan keputusan operasional kantin. Pengelola dapat menggunakan insight ini untuk meningkatkan stok bahan baku Nasi Goreng, menempatkannya sebagai menu unggulan promosi, atau mengevaluasi menu dengan pendapatan terendah.

# %% [markdown]
# **Lembar Perencanaan Proyek Kelompok (Project Charter)**
#
#
# Kategori | Isian / Rencana |
# | :--- | :--- |
# | **Nama Anggota Kelompok** | 1. Salsabila Syifa N. <br> 2.Yasmin Pratiwi |
# | **Dataset yang Dipilih** | ☑ Data Nilai Akademik Siswa |
# | **Pertanyaan Analisis Awal** | 1. Siapa saja 5 siswa dengan nilai akhir tertinggi di angkatan?<br>2. Kelas mana yang memiliki rata-rata nilai paling baik?<br>3. Berapa banyak siswa yang berstatus Remedial? |
# | **Dugaan Masalah Kualitas Data** | ☑ Missing value pada kolom: `nilai`, `nama`<br>☑ Duplikat data<br>☐ Tipe data tidak sesuai |
# | **Rencana Teknik Pembersihan** | • `drop_duplicates()` untuk menghapus baris duplikat identik.<br>• `fillna(0)` untuk mengisi data nilai yang kosong.<br>• `dropna()` untuk menghapus baris jika nama siswa kosong. |
# | **Rencana Manipulasi Data** | **Filter:** Menyaring siswa yang nilainya di bawah KKM.<br>**Sort:** Mengurutkan siswa dari nilai tertinggi ke terendah.<br>**Kolom turunan:** Membuat kolom 'Status' (Lulus / Remedial).<br>**Groupby/agregasi:** Menghitung rata-rata nilai berdasarkan kelas. |
# | **Jadwal Kerja** | **P3 (Loading & Inspection):** [Isi Tanggal]<br>**P4 (Cleaning):** [Isi Tanggal]<br>**P5 (Manipulation):** [Isi Tanggal]<br>**P6 (Uji & Presentasi):** [Isi Tanggal] |
# | **Pembagian Peran** | **Anggota 1 (Yasmin Pratiwi):** Mengerjakan kode Data Loading, Inspection, & Cleaning.<br> **Anggota 2 ([Salsabila Syifa N.]):** Mengerjakan Data Manipulation, pembuatan CSV, & Profiling Summary. |

# %%
import pandas as pd
import numpy as np

# ==========================================
# TAHAP 1: Data Loading & Inspection
# ==========================================
print("--- TAHAP 1: INSPEKSI DATA ---")
# Memuat data dari file CSV
df = pd.read_csv('/dataset_nilai_akademik_siswa.csv')

print(df.head()) # Menampilkan 5 baris pertama
print(df.info()) # Melihat tipe data dan data yang kosong
print(df.describe()) # Statistik ringkas
print("Ukuran dataset (baris, kolom):", df.shape)

# ==========================================
# TAHAP 2: Data Cleaning
# ==========================================
print("\n--- TAHAP 2: PEMBERSIHAN DATA ---")
# 1. Menghapus data yang duplikat
df = df.drop_duplicates()

# 2. Menangani nilai kosong (missing value)
# CATATAN: Jika nama kolom nilainya bukan 'nilai', ganti kata 'nilai' di bawah ini
df['nilai'] = df['nilai'].fillna(0)

# Jika ada kolom nama yang kosong, barisnya dihapus (hilangkan tanda # untuk menjalankan)
# df = df.dropna(subset=['nama'])

print("Pembersihan selesai! Ukuran dataset sekarang:", df.shape)
print("\n--- TAHAP 3: MANIPULASI DATA ---")


# [KODE PERBAIKAN] Menghapus kata 'poin', mengubah koma jadi titik, membersihkan spasi, lalu mengubah ke angka desimal
df['nilai'] = df['nilai'].astype(str).str.replace('poin', '', case=False).str.replace(',', '.').str.strip().astype(float)

# 1. Kolom Turunan: Membuat kolom status Lulus/Remedial (KKM = 75)
df['status'] = np.where(df['nilai'] >= 75, 'Lulus', 'Remedial')

# 2. Filtering: Menampilkan jumlah siswa yang remedial
siswa_remedial = df[df['status'] == 'Remedial']
print(f"Jumlah siswa yang remedial: {len(siswa_remedial)} anak")

# 3. Sorting: Mengurutkan 5 siswa dengan nilai tertinggi
ranking = df.sort_values(by='nilai', ascending=False)
print("\nTop 5 Siswa dengan Nilai Tertinggi:")
print(ranking[['nama', 'kelas', 'nilai']].head())

# 4. Groupby: Menghitung rata-rata nilai per kelas
rata_kelas = df.groupby('kelas')['nilai'].mean().reset_index()
print("\nRata-rata Nilai per Kelas:")
print(rata_kelas)

# ==========================================
# TAHAP 4: Menyimpan Dataset Bersih
# ==========================================
df.to_csv('dataset_nilai_bersih.csv', index=False)
print("\nDataset bersih telah berhasil disimpan menjadi 'dataset_nilai_bersih.csv'")
# Out:
# --- TAHAP 1: INSPEKSI DATA ---
#   id_siswa           nama     kelas   mata_pelajaran jenis_ujian  \
# 0  SIS0004  Joko Prasetyo  XI RPL 2              KKA         uas
# 1  SIS0020      Eka Putri  XI RPL 1              PKK         uts
# 2  SIS0015  Nanda Pratama  XI RPL 3  Pemrograman Web         UAS
# 3  SIS0046  Fajar Nugroho  XI RPL 2       Matematika          UH
# 4  SIS0011    Ayu Lestari  XI RPL 2  Pemrograman Web          UH
#
#      tanggal_ujian nilai guru_pengampu
# 0       06/08/2026    46      Ibu Wati
# 1  12 Agustus 2026  73,0  Bpk. Santoso
# 2       2026-08-15    69  Bpk. Santoso
# 3       10/08/2026    73   Bpk. Arifin
# 4   6 Agustus 2026    53      Ibu Wati
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_siswa        79 non-null     object
#  1   nama            79 non-null     object
# ...

# %% [markdown]
# **E. Data Profiling Summary (Bahan Presentasi)**
#
# Berdasarkan proses *Data Loading & Inspection*, dataset nilai akademik awal kami ternyata cukup kotor. Kami menemukan bahwa kolom 'nilai' tidak bisa dihitung karena terbaca sebagai teks. Hal ini disebabkan oleh adanya penulisan angka menggunakan tanda koma (contoh: 73,0) dan adanya satuan teks (contoh: "67 poin"). Kami harus membersihkan teks tersebut terlebih dahulu dan mengubah tipe datanya menjadi angka (*float*). Selain itu, kami juga mengisi kekosongan data (*missing value*) pada nilai ujian dengan angka nol, karena asumsi kami siswa tersebut tidak mengikuti ujian.
#
# Setelah dataset bersih, kami melakukan manipulasi data. Melalui fungsi *groupby*, kami menemukan perbandingan rata-rata nilai antar kelas. Dengan menambahkan kolom turunan (*Status* Kelulusan) dan melakukan *filtering*, kami berhasil mengidentifikasi secara cepat siswa mana saja yang memerlukan program ujian remedial.

# %% [markdown]
# **B.7 Lembar Refleksi Proyek **
#
# **6. Tahap mana yang paling menantang bagi kelompokmu, dan bagaimana kalian mengatasinya?**
#
# Jawaban:
#
# Tahap yang paling menantang adalah *Data Cleaning*. Kami sempat mengalami *error* berkali-kali (seperti `ValueError`) saat mencoba menentukan status Lulus/Remedial. Ternyata penyebabnya adalah kolom nilai mengandung karakter teks (seperti kata "poin" dan koma). Kami mengatasinya dengan mengeksplorasi fungsi `.replace()` untuk membuang teks tersebut, lalu memaksanya berubah menjadi angka menggunakan `.astype(float)`.

# %% [markdown]
# **7. Menurutmu, mengapa keputusan membersihkan data perlu didasarkan pada alasan yang jelas, bukan asal-asalan?**
#
# Jawaban:
#
# Karena pembersihan data yang asal-asalan akan memanipulasi fakta. Misalnya, jika kami langsung menghapus (*drop*) baris siswa yang nilainya kosong, rata-rata kelas akan terlihat tinggi dan tidak merepresentasikan keadaan aslinya. Pengambilan keputusan penanganan data harus disesuaikan dengan konteks logis datanya.

# %% [markdown]
# **8. Apa hubungan antara dataset bersih hasil proyek ini dengan pekerjaan seorang Data Analyst di dunia nyata?**
#
# Jawaban:
#
# Di dunia kerja nyata, data dari sistem sekolah atau perusahaan hampir selalu berantakan dan tidak konsisten (seperti format penulisan angka yang berbeda-beda tadi). Proyek ini menyadarkan kami bahwa tugas utama seorang Data Analyst bukanlah sekadar membuat grafik, melainkan memastikan data tersebut divalidasi dan dibersihkan (*Data Cleaning*) terlebih dahulu agar siap dan akurat saat dianalisis.
